# %% [markdown]
# Importing Required python Module

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %% [markdown]
# Importing Datasets

# %%
df = pd.read_csv(r"E:\ml_deployment\wine_quality_prediction\winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# 1598            6.0             0.310         0.47  ...       0.66     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.info()
df.describe().T.style.background_gradient(axis=0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# <style type="text/css">
# #T_75db4_row0_col0, #T_75db4_row1_col0, #T_75db4_row1_col7, #T_75db4_row2_col0, #T_75db4_row2_col3, #T_75db4_row2_col4, #T_75db4_row2_col7, #T_75db4_row3_col0, #T_75db4_row4_col0, #T_75db4_row4_col1, #T_75db4_row4_col2, #T_75db4_row4_col3, #T_75db4_row4_col4, #T_75db4_row4_col5, #T_75db4_row4_col6, #T_75db4_row4_col7, #T_75db4_row5_col0, #T_75db4_row6_col0, #T_75db4_row7_col0, #T_75db4_row7_col2, #T_75db4_row7_col7, #T_75db4_row8_col0, #T_75db4_row9_col0, #T_75db4_row10_col0, #T_75db4_row11_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_75db4_row0_col1, #T_75db4_row10_col6 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_75db4_row0_col2, #T_75db4_row0_col7, #T_75db4_row3_col1, #T_75db4_row3_col5, #T_75db4_row3_col7, #T_75db4_row8_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_75db4_row0_col3 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_75db4_row0_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_75db4_row0_col5 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_75db4_row0_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_75db4_row1_col1, #T_75db4_row1_col5, #T_75db4_row1_col6, #T_75db4_row9_col6 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_75db4_row1_col2, #T_75db4_row2_col1, #T_75db4_row2_col2, #T_75db4_row2_col5, #T_75db4_row2_col6, #T_75db4_row8_col2, #T_75db4_row9_col2, #T_75db4_row9_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_75db4_row1_col3, #T_75db4_row1_col4, #T_75db4_row7_col6, #T_75db4_row8_col7, #T_75db4_row9_col1, #T_75db4_row9_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_75db4_row3_col2, #T_75db4_row3_col6, #T_75db4_row7_col4, #T_75db4_row9_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_75db4_row3_col3 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_75db4_row3_col4, #T_75db4_row8_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_75db4_row5_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_75db4_row5_col2 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_75db4_row5_col3, #T_75db4_row7_col3, #T_75db4_row11_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_75db4_row5_col4 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_75db4_row5_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_75db4_row5_col6 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_75db4_row5_col7 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_75db4_row6_col1, #T_75db4_row6_col2, #T_75db4_row6_col4, #T_75db4_row6_col5, #T_75db4_row6_col6, #T_75db4_row6_col7, #T_75db4_row10_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_75db4_row6_col3 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_75db4_row7_col1, #T_75db4_row9_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_75db4_row7_col5, #T_75db4_row11_col2, #T_75db4_row11_col7 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_75db4_row8_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_75db4_row8_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_75db4_row8_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_75db4_row10_col1, #T_75db4_row11_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_75db4_row10_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_75db4_row10_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_75db4_row10_col5 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_75db4_row10_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_75db4_row11_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_75db4_row11_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_75db4_row11_col6 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# </style>
# <table id="T_75db4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75db4_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_75db4_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_75db4_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_75db4_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_75db4_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_75db4_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_75db4_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_75db4_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75db4_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_75db4_row0_col0" class="data row0 col0" >1599.000000</td>
#       <td id="T_75db4_row0_col1" class="data row0 col1" >8.319637</td>
#       <td id="T_75db4_row0_col2" class="data row0 col2" >1.741096</td>
#       <td id="T_75db4_row0_col3" class="data row0 col3" >4.600000</td>
#       <td id="T_75db4_row0_col4" class="data row0 col4" >7.100000</td>
#       <td id="T_75db4_row0_col5" class="data row0 col5" >7.900000</td>
#       <td id="T_75db4_row0_col6" class="data row0 col6" >9.200000</td>
#       <td id="T_75db4_row0_col7" class="data row0 col7" >15.900000</td>
#     </tr>
#     <tr>
#       <th id="T_75db4_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_75db4_row1_col0" class="data row1 col0" >1599.000000</td>
#       <td id="T_75db4_row1_col1" class="data row1 col1" >0.527821</td>
#       <td id="T_75db4_row1_col2" class="data row1 col2" >0.179060</td>
#       <td id="T_75db4_row1_col3" class="data row1 col3" >0.120000</td>
#       <td id="T_75db4_row1_col4" class="data row1 col4" >0.390000</td>
#       <td id="T_75db4_row1_col5" class="data row1 col5" >0.520000</td>
#       <td id="T_75db4_row1_col6" class="data row1 col6" >0.640000</td>
#       <td id="T_75db4_row1_col7" class="data row1 col7" >1.580000</td>
#     </tr>
#     <tr>
#       <th id="T_75db4_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_75db4_row2_col0" class="data row2 col0" >1599.000000</td>
#       <td id="T_75db4_row2_col1" class="data row2 col1" >0.270976</td>
#       <td id="T_75db4_row2_col2" class="data row2 col2" >0.194801</td>
#       <td id="T_75db4_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_75db4_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_75db4_row2_col5" class="data row2 col5" >0.260000</td>
#       <td id="T_75db4_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_75db4_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75db4_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_75db4_row3_col0" class="data row3 col0" >1599.000000</td>
#       <td id="T_75db4_row3_col1" class="data row3 col1" >2.538806</td>
#       <td id="T_75db4_row3_col2" class="data row3 col2" >1.409928</td>
#       <td id="T_75db4_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_75db4_row3_col4" class="data row3 col4" >1.900000</td>
#       <td id="T_75db4_row3_col5" class="data row3 col5" >2.200000</td>
#       <td id="T_75db4_row3_col6" class="data row3 col6" >2.600000</td>
#       <td id="T_75db4_row3_col7" class="data row3 col7" >15.500000</td>
#     </tr>
#     <tr>
#       <th id="T_75db4_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_75db4_row4_col0" class="data row4 col0" >1599.000000</td>
#       <td id="T_75db4_row4_col1" class="data row4 col1" >0.087467</td>
#       <td id="T_75db4_row4_col2" class="data row4 col2" >0.047065</td>
#       <td id="T_75db4_row4_col3" class="data row4 col3" >0.012000</td>
#       <td id="T_75db4_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_75db4_row4_col5" class="data row4 col5" >0.079000</td>
#       <td id="T_75db4_row4_col6" class="data row4 col6" >0.090000</td>
#       <td id="T_75db4_row4_col7" class="data row4 col7" >0.611000</td>
#     </tr>
#     <tr>
#       <th id="T_75db4_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td id="T_75db4_row5_col0" class="data row5 col0" >159

# %% [markdown]
# The table shows summary statistics (like mean, std, min, max) for each feature in the wine dataset. The color gradient highlights higher and lower values, making it easy to spot features with large ranges or potential outliers. This helps quickly understand the distribution and scale of each variable.

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print(f"Values present in Quality Column :{df['quality'].unique()}")
# Out:
# Values present in Quality Column :[5 6 7 4 8 3]

# %% [markdown]
# Mapping the Values Based on quility Score of the red wine

# %%
df = df.replace({
    "quality":{
        8:'Good',
        7:'Good',
        6:'Average',
        5:'Average',
        4:'Bad',
        3:'Bad'
    }
})
df
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4  Average
# 1               7.8             0.880         0.00  ...       0.68      9.8  Average
# 2               7.8             0.760         0.04  ...       0.65      9.8  Average
# 3              11.2             0.280         0.56  ...       0.58      9.8  Average
# 4               7.4             0.700         0.00  ...       0.56      9.4  Average
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5  Average
# 1595            5.9             0.550         0.10  ...       0.76     11.2  Average
# 1596            6.3             0.510         0.13  ...       0.75     11.0  Average
# 1597            5.9             0.645         0.12  ...       0.71     10.2  Average
# 1598            6.0             0.310         0.47  ...       0.66     11.0  Average
#
# [1599 rows x 12 columns]
